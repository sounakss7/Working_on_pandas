# %%
import pandas as pd
import numpy as np
var=pd.DataFrame({"A": [1, 2, 3], "B": [4, 5,6]})
var["C"] = var["A"] + var["B"]
var.insert(2,"D", np.random.randn(3))
print(var)
print()
var.pop("D")
print(var)
print()
var["C"]=var["A"]>2
print(var)
# Out:
#    A  B         D  C
# 0  1  4  1.669321  5
# 1  2  5 -0.424353  7
# 2  3  6  0.804452  9
#
#    A  B  C
# 0  1  4  5
# 1  2  5  7
# 2  3  6  9
#
#    A  B      C
# 0  1  4  False
# 1  2  5  False
# 2  3  6   True

# %%
import pandas as pd
csv_1=pd.read_csv("C:\\Users\\souna\\Downloads\\consumers-price-index-june-2024-quarter-index-numbers.csv",nrows=5,usecols=[0,2,3,4])
csv_1
# Out:
#   Series_reference  Data_value STATUS  UNITS
# 0       CPIQ.SE901   13.167858  FINAL  Index
# 1       CPIQ.SE901    0.000000  FINAL  Index
# 2       CPIQ.SE901    0.000000  FINAL  Index
# 3       CPIQ.SE901    0.000000  FINAL  Index
# 4       CPIQ.SE901    0.000000  FINAL  Index

# %%
import pandas as pd
csv_1=pd.read_csv("C:\\Users\\souna\\Downloads\\consumers-price-index-june-2024-quarter-index-numbers.csv",index_col="STATUS")
csv_1
# Out:
#        Series_reference   Period   Data_value  UNITS Subject  \
# STATUS
# FINAL        CPIQ.SE901  1914.06    13.167858  Index     CPI
# FINAL        CPIQ.SE901  1914.09     0.000000  Index     CPI
# FINAL        CPIQ.SE901  1914.12     0.000000  Index     CPI
# FINAL        CPIQ.SE901  1915.03     0.000000  Index     CPI
# FINAL        CPIQ.SE901  1915.06     0.000000  Index     CPI
# ...                 ...      ...          ...    ...     ...
# FINAL         CPIQ.SE9A  2023.06  1231.000000  Index     CPI
# FINAL         CPIQ.SE9A  2023.09  1253.000000  Index     CPI
# FINAL         CPIQ.SE9A  2023.12  1259.000000  Index     CPI
# FINAL         CPIQ.SE9A  2024.03  1267.000000  Index     CPI
# FINAL         CPIQ.SE9A  2024.06  1272.000000  Index     CPI
#
#                                      Group Series_title_1  Series_title_2
# STATUS
# FINAL   CPI Level 1 Groups for New Zealand           Food             NaN
# ...

# %%
import pandas as pd
csv_1=pd.read_csv("C:\\Users\\souna\\Downloads\\consumers-price-index-june-2024-quarter-index-numbers.csv",header=2)
csv_1
# Out:
#        CPIQ.SE901  1914.09            0  FINAL  Index  CPI  \
# 0      CPIQ.SE901  1914.12     0.000000  FINAL  Index  CPI
# 1      CPIQ.SE901  1915.03     0.000000  FINAL  Index  CPI
# 2      CPIQ.SE901  1915.06     0.000000  FINAL  Index  CPI
# 3      CPIQ.SE901  1915.09    14.919183  FINAL  Index  CPI
# 4      CPIQ.SE901  1915.12     0.000000  FINAL  Index  CPI
# ...           ...      ...          ...    ...    ...  ...
# 21388   CPIQ.SE9A  2023.06  1231.000000  FINAL  Index  CPI
# 21389   CPIQ.SE9A  2023.09  1253.000000  FINAL  Index  CPI
# 21390   CPIQ.SE9A  2023.12  1259.000000  FINAL  Index  CPI
# 21391   CPIQ.SE9A  2024.03  1267.000000  FINAL  Index  CPI
# 21392   CPIQ.SE9A  2024.06  1272.000000  FINAL  Index  CPI
#
#        CPI Level 1 Groups for New Zealand        Food  NA
# 0      CPI Level 1 Groups for New Zealand        Food NaN
# 1      CPI Level 1 Groups for New Zealand        Food NaN
# 2      CPI Level 1 Groups for New Zealand        Food NaN
# ...

# %%
import pandas as pd
csv_1=pd.read_csv("C:\\Users\\souna\\Downloads\\consumers-price-index-june-2024-quarter-index-numbers.csv",names=["sounak","mandril","arka","amit","kaka"])
csv_1
# Out:
#                                                  sounak  mandril  \
# Series_reference Period  Data_value       STATUS  UNITS  Subject
# CPIQ.SE901       1914.06 13.1678579027356 FINAL   Index      CPI
#                  1914.09 0                FINAL   Index      CPI
#                  1914.12 0                FINAL   Index      CPI
#                  1915.03 0                FINAL   Index      CPI
# ...                                                 ...      ...
# CPIQ.SE9A        2023.06 1231             FINAL   Index      CPI
#                  2023.09 1253             FINAL   Index      CPI
#                  2023.12 1259             FINAL   Index      CPI
#                  2024.03 1267             FINAL   Index      CPI
#                  2024.06 1272             FINAL   Index      CPI
#
#                                                                                 arka  \
# Series_reference Period  Data_value       STATUS                               Group
# ...
